# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import time
from time import sleep
import csv

driver = webdriver.Chrome()

# driver.get method() will navigate to a page given by the URL address
driver.get("https://linkedin.com/login")


# Logging into LinkedIn
time.sleep(2)
  
username = driver.find_element_by_id("username")
username.send_keys("nanhtrang289@gmail.com") 
  
pword = driver.find_element_by_id("password")
pword.send_keys("ganhy1102")     
  
login = driver.find_element_by_xpath('//*[@id="organic-div"]/form/div[3]/button')
print('Loading...')
login.click()

search_f = driver.find_element_by_xpath('//*[@id="global-nav-typeahead"]/input')
print('Loading...')
# tukhoa = input('nhap từ khóa:')
# search_f.send_keys("tukhoa")

search_f.send_keys("remote")
search_f.send_keys(Keys.RETURN)

driver.get("https://www.linkedin.com/jobs/search/?f_E=2&f_JT=F&geoId=92000000&keywords=remote&location=Worldwide&sortBy=R%2F")
time.sleep(5)
# Out:
# C:\Users\DELL\AppData\Local\Temp/ipykernel_17028/1662811533.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   username = driver.find_element_by_id("username")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_17028/1662811533.py:21: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pword = driver.find_element_by_id("password")
# C:\Users\DELL\AppData\Local\Temp/ipykernel_17028/1662811533.py:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   login = driver.find_element_by_xpath('//*[@id="organic-div"]/form/div[3]/button')
# vy1-----------------
# C:\Users\DELL\AppData\Local\Temp/ipykernel_17028/1662811533.py:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_f = driver.find_element_by_xpath('//*[@id="global-nav-typeahead"]/input')
# vy2++++++++++++++++

# %%
def GetURL():
    driver.get(link)
    lastHeight = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(5)
        newHeight = driver.execute_script("return document.body.scrollHeight")
        if newHeight == lastHeight:
            break
        lastHeight = newHeight
    time.sleep(5)
    page_source = BeautifulSoup(driver.page_source, "html.parser")
    
    
    #info_div = page_source.find('div',{'class':'jobs-search-results display-flex flex-column'})
    info_div = page_source.find('ul',{'class':'jobs-search-results__list list-style-none'})
    sleep(2)

    profiles = info_div.find_all('a', class_ = 'disabled ember-view job-card-container__link')
    sleep(2)
    

    all_profile_URL = []
    for profile in profiles:
        profile_ID = profile.get('href')
        profile_URL = "https://www.linkedin.com" + profile_ID
        if profile_URL not in all_profile_URL:
            all_profile_URL.append(profile_URL)
        sleep(2)
    #print(all_profile_URL)
    return all_profile_URL

# %%
j=0
page=0
URLs_all_page = []
URL = "https://www.linkedin.com/jobs/search/?f_E=2&f_JT=F&geoId=92000000&keywords=remote&location=Worldwide&sortBy=R%2F"
for j in range(40):
    link = URL + "&start="+str(page)
    #print(link)
    URLs_one_page = GetURL()
    lastHeight = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(5)
        newHeight = driver.execute_script("return document.body.scrollHeight")
        if newHeight == lastHeight:
            break
        lastHeight = newHeight
    
    URLs_all_page = URLs_all_page + URLs_one_page
    page+=25

# %%
with open('output.csv', 'w', encoding='utf-8',  newline = '') as file_output:
    headers = ['Title', 'Name', 'Type','Time', 'Location' ,'Number of applying','URL' ]
    writer = csv.DictWriter(file_output, delimiter=',', lineterminator='\n',fieldnames=headers)
    writer.writeheader()
    for linkedin_URL in URLs_all_page:
        driver.get(linkedin_URL)
        #print('- Accessing profile: ', linkedin_URL)
        sleep(3)
        page_source = BeautifulSoup(driver.page_source, "html.parser")
        info_div = page_source.find('div',{'class':'p5'})
        try:
            ten_cong_viec = info_div.find('h1', class_='t-24 t-bold').get_text().strip() #Remove unnecessary characters 
            print('--- Tên công việc là: ', ten_cong_viec)
        except:
            ten_cong_viec = None
            print('--- Tên công việc là: ', ten_cong_viec)

        try:
            ten_cong_ty = info_div.find('a', class_='ember-view t-black t-normal').get_text().strip() 
            print('--- Tên công ty là: ', ten_cong_ty)
        except:
            ten_cong_ty = None
            print('--- Tên công ty là: ', ten_cong_ty)

        try:
            loai_cong_viec = info_div.find('div', class_='jobs-unified-top-card__job-insight').get_text().strip() 
            print('--- Loại công việc: ', loai_cong_viec)
        except:
            loai_cong_viec = None
            print('--- Loại công việc: ', loai_cong_viec)

        try:
            luong = info_div.find('a', class_='app-aware-link').get_text().strip() 
            print('--- Lương: ', luong)
        except:
            luong = None
            print('--- Lương: ', luong)

        try:
            vi_tri = info_div.find('span', class_='jobs-unified-top-card__bullet').get_text().strip() 
            print('--- Vị trí: ', vi_tri)
        except:
            vi_tri = None
            print('--- Vị trí: ', vi_tri)

        try:
            tg_dang  = info_div.find('span', class_='jobs-unified-top-card__posted-date').get_text().strip() 
            print('--- Thời gian đăng: ', tg_dang )
        except:
            tg_dang = None
            print('--- Thời gian đăng: ', tg_dang )

        try:
            nguoi_dang_ki = info_div.find('span', class_='jobs-unified-top-card__applicant-count').get_text().strip()
            print('--- Số lượng người đăng kí: ', nguoi_dang_ki)
        except:
            nguoi_dang_ki = None
            print('--- Số lượng người đăng kí: ', nguoi_dang_ki)

        writer.writerow({headers[0]:ten_cong_viec, headers[1]:ten_cong_ty, headers[2]:loai_cong_viec, headers[3]:tg_dang, headers[4]:vi_tri,headers[5]:nguoi_dang_ki, headers[6]:linkedin_URL})
        print('-----------------------------\n')
        
    

print('Nhiệm vụ hoàn thành!')
# Out:
# --- Tên công việc là:  Information Technology Engineering & Operations Specialist
# --- Tên công ty là:  Brooks Running
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Vietnam
# --- Thời gian đăng:  1 week ago
# --- Số lượng người đăng kí:  3 applicants
# -----------------------------
#
# --- Tên công việc là:  Python Software Engineer (Open Remote)
# --- Tên công ty là:  Wizeline
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# --- Thời gian đăng:  2 weeks ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Web Application Developer, Upland (Remote) - $60,000/year USD
# --- Tên công ty là:  Crossover for Work
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Hanoi, Hanoi, Vietnam
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Community Content Management Specialist - VN
# --- Tên công ty là:  TikTok
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Ho Chi Minh City, Vietnam
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  20 applicants
# -----------------------------
#
# --- Tên công việc là:  Junior Software Architect| Remote
# --- Tên công ty là:  InnoTech.pt
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Lisbon, Lisbon, Portugal
# --- Thời gian đăng:  2 hours ago
# --- Số lượng người đăng kí:  6 applicants
# -----------------------------
#
# --- Tên công việc là:  Frontend Developer (Remote)
# --- Tên công ty là:  CRISP STUDIO
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Armenia
# --- Thời gian đăng:  5 hours ago
# --- Số lượng người đăng kí:  47 applicants
# -----------------------------
#
# --- Tên công việc là:  DevOps Engineer
# --- Tên công ty là:  Binance
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# --- Thời gian đăng:  1 week ago
# --- Số lượng người đăng kí:  6 applicants
# -----------------------------
#
# --- Tên công việc là:  Vue.js Software Engineer
# --- Tên công ty là:  Wizeline
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# --- Thời gian đăng:  2 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  QA Engineer (C2C)
# --- Tên công ty là:  Binance
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# --- Thời gian đăng:  1 week ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Quality Analysis and Operations Specialist-VN
# --- Tên công ty là:  TikTok
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Ho Chi Minh City, Vietnam
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  21 applicants
# -----------------------------
#
# --- Tên công việc là:  Product Designer - Ho Chi Minh, Vietnam
# --- Tên công ty là:  Limeade
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Ho Chi Minh City, Ho Chi Minh City, Vietnam
# --- Thời gian đăng:  1 week ago
# --- Số lượng người đăng kí:  3 applicants
# -----------------------------
#
# --- Tên công việc là:  Platform Engineer
# --- Tên công ty là:  betterplace.org
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Lithuania
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  4 applicants
# -----------------------------
#
# --- Tên công việc là:  Platform Engineer
# --- Tên công ty là:  betterplace.org
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Latvia
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  3 applicants
# -----------------------------
#
# --- Tên công việc là:  Software Engineer
# --- Tên công ty là:  CryptoSimple
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  European Union
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  154 applicants
# -----------------------------
#
# --- Tên công việc là:  Software Development Engineer in Test
# --- Tên công ty là:  Chainlink Labs
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Berlin, Berlin, Germany
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  22 applicants
# -----------------------------
#
# --- Tên công việc là:  Online MCAT Tutor
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  United States
# --- Thời gian đăng:  4 days ago
# --- Số lượng người đăng kí:  4 applicants
# -----------------------------
#
# --- Tên công việc là:  NasdaqTop10 - QA - Remote - Salary 70 000€
# --- Tên công ty là:  FRG Technology Consulting
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Antwerp Metropolitan Area
# --- Thời gian đăng:  1 day ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  PHP Developer - Remote
# --- Tên công ty là:  Lee Enterprises
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  United States
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  55 applicants
# -----------------------------
#
# --- Tên công việc là:  Nepali Transcriber/ QA  (ट्रान्सक्राइबर/ QA - नेपाली)
# --- Tên công ty là:  TransPerfect
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Lalitpur District, Nepal
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  9 applicants
# -----------------------------
#
# --- Tên công việc là:  Nepali Transcriber/ QA  (ट्रान्सक्राइबर/ QA - नेपाली)
# --- Tên công ty là:  TransPerfect
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Nepal
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  11 applicants
# -----------------------------
#
# --- Tên công việc là:  Self Employed
# --- Tên công ty là:  Lets Create Success
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  United Kingdom
# --- Thời gian đăng:  9 hours ago
# --- Số lượng người đăng kí:  70 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  New Zealand
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Blockchain Developer
# --- Tên công ty là:  Startup Slang
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Tunisia
# --- Thời gian đăng:  3 hours ago
# --- Số lượng người đăng kí:  7 applicants
# -----------------------------
#
# --- Tên công việc là:  Seattle ISEE- Middle Level Tutor
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Seattle, WA
# --- Thời gian đăng:  4 days ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Quality Assurance Automation Engineer
# --- Tên công ty là:  Virtualmind
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Brazil
# --- Thời gian đăng:  5 days ago
# --- Số lượng người đăng kí:  8 applicants
# -----------------------------
#
# --- Tên công việc là:  Desarrollador/a Elasticksearch. Remoto
# --- Tên công ty là:  Indizen - Scalian Group
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Madrid, Community of Madrid, Spain
# --- Thời gian đăng:  4 days ago
# --- Số lượng người đăng kí:  3 applicants
# -----------------------------
#
# --- Tên công việc là:  Plano Web Development Tutor
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Plano, TX
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  South Korea
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Onboarding Developer - Remote
# --- Tên công ty là:  Lee Enterprises
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  United States
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  4 applicants
# -----------------------------
#
# --- Tên công việc là:  Miami Computer Programming Expert
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Miami, FL
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Nepali Transcriber/ QA  (ट्रान्सक्राइबर/ QA - नेपाली)
# --- Tên công ty là:  TransPerfect
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Nepalganj, Bherī, Nepal
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  4 applicants
# -----------------------------
#
# --- Tên công việc là:  Desarrollador web
# --- Tên công ty là:  Aluxion
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Spain
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  NasdaqTop10 - QA - Remote - Salary 70 000€
# --- Tên công ty là:  FRG Technology Consulting
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Liège, Walloon Region, Belgium
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Flutter Developer
# --- Tên công ty là:  Webkox
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  India
# --- Thời gian đăng:  7 hours ago
# --- Số lượng người đăng kí:  40 applicants
# -----------------------------
#
# --- Tên công việc là:  Software Engineer
# --- Tên công ty là:  Genophore Inc.
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Egypt
# --- Thời gian đăng:  2 hours ago
# --- Số lượng người đăng kí:  40 applicants
# -----------------------------
#
# --- Tên công việc là:  Join Our Talent Network!
# --- Tên công ty là:  Hitachi Vantara
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Hitachi, Ibaraki, Japan
# --- Thời gian đăng:  4 days ago
# --- Số lượng người đăng kí:  23 applicants
# -----------------------------
#
# --- Tên công việc là:  Software Engineer
# --- Tên công ty là:  Contobox
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Greater Montreal Metropolitan Area
# --- Thời gian đăng:  8 hours ago
# --- Số lượng người đăng kí:  36 applicants
# -----------------------------
#
# --- Tên công việc là:  Software Engineer
# --- Tên công ty là:  Contobox
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Greater Toronto Area, Canada
# --- Thời gian đăng:  8 hours ago
# --- Số lượng người đăng kí:  57 applicants
# -----------------------------
#
# --- Tên công việc là:  Anwendungstechniker
# --- Tên công ty là:  Ecoratio Deutschland
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Germany
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  3 applicants
# -----------------------------
#
# --- Tên công việc là:  UTIC: DevOps (Ukraine)
# --- Tên công ty là:  Luxoft
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Ukraine
# --- Thời gian đăng:  5 days ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Kick-start your career with Zuhlke
# --- Tên công ty là:  Zühlke Group
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Bulgaria
# --- Thời gian đăng:  4 days ago
# --- Số lượng người đăng kí:  3 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Ecuador
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Linux Systems Administrator - REMOTE
# --- Tên công ty là:  Dice
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Georgia, United States
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  35 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Argentina
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  SRE I (Observability)
# --- Tên công ty là:  Dock
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Brazil
# --- Thời gian đăng:  5 days ago
# --- Số lượng người đăng kí:  30 applicants
# -----------------------------
#
# --- Tên công việc là:  Back End Developer
# --- Tên công ty là:  Virtualmind
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Ecuador
# --- Thời gian đăng:  5 days ago
# --- Số lượng người đăng kí:  11 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Kenya
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  14 applicants
# -----------------------------
#
# --- Tên công việc là:  Support Advisor (Remote, New Zealand)
# --- Tên công ty là:  Shopify
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  New Zealand
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  13 applicants
# -----------------------------
#
# --- Tên công việc là:  Test Automation Specialist
# --- Tên công ty là:  RailVision Analytics
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Montreal, QC
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  11 applicants
# -----------------------------
#
# --- Tên công việc là:  Research Engineer
# --- Tên công ty là:  Chainlink Labs
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Gothenburg, Vastra Gotaland County, Sweden
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  9 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Dominican Republic
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  POS Tester (100% Remote)
# --- Tên công ty là:  Dice
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  United States
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  10 applicants
# -----------------------------
#
# --- Tên công việc là:  DevOps Engineer
# --- Tên công ty là:  Virtualmind
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Peru
# --- Thời gian đăng:  5 days ago
# --- Số lượng người đăng kí:  10 applicants
# -----------------------------
#
# --- Tên công việc là:  Desenvolvedor Frontend - HTML/CSS Pleno
# --- Tên công ty là:  Revelo Brasil
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Brazil
# --- Thời gian đăng:  1 hour ago
# --- Số lượng người đăng kí:  37 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Morocco
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  4 applicants
# -----------------------------
#
# --- Tên công việc là:  Softwareentwickler (w/m/d) - remote
# --- Tên công ty là:  Deutsche Bahn
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Leipzig, Saxony, Germany
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  2 applicants
# -----------------------------
#
# --- Tên công việc là:  Call Handler (Work from home)
# --- Tên công ty là:  Adecco
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Leicestershire, England, United Kingdom
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  41 applicants
# -----------------------------
#
# --- Tên công việc là:  Bilingual Quality Agent
# --- Tên công ty là:  Cornershop by Uber
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Toronto, ON
# --- Thời gian đăng:  4 days ago
# --- Số lượng người đăng kí:  11 applicants
# -----------------------------
#
# --- Tên công việc là:  Web Developer
# --- Tên công ty là:  Twik
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Dallas-Fort Worth Metroplex
# --- Thời gian đăng:  12 hours ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Costa Rica
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Software Engineer
# --- Tên công ty là:  Neuraspace
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Portugal
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  66 applicants
# -----------------------------
#
# --- Tên công việc là:  *REMOTE WORKING* Online / Network Programmer – PC and Console Games
# --- Tên công ty là:  OPMjobs
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  London, England, United Kingdom
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Full Stack Developer
# --- Tên công ty là:  Chainlink Labs
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Sydney, New South Wales, Australia
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  8 applicants
# -----------------------------
#
# --- Tên công việc là:  Conversion Engineer I (Remote)
# --- Tên công ty là:  Vertafore
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  United States
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  NFT Game Developer
# --- Tên công ty là:  None
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Ukraine
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  5 applicants
# -----------------------------
#
# --- Tên công việc là:  Tier 3 - Technical Support Specialist
# --- Tên công ty là:  ABC Fitness Solutions
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Vancouver, BC
# --- Thời gian đăng:  5 days ago
# --- Số lượng người đăng kí:  24 applicants
# -----------------------------
#
# --- Tên công việc là:  Junior Developer - C++/Python - REMOTE
# --- Tên công ty là:  Alvaria, Inc.
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Cracow, Małopolskie, Poland
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  58 applicants
# -----------------------------
#
# --- Tên công việc là:  New Orleans ISEE- Middle Level Tutor
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  New Orleans, LA
# --- Thời gian đăng:  4 days ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Bosnia and Herzegovina
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Site Reliability Engineer
# --- Tên công ty là:  Chainlink Labs
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Dublin, County Dublin, Ireland
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  4 applicants
# -----------------------------
#
# --- Tên công việc là:  Call Center Representative - Remote WI
# --- Tên công ty là:  Gainwell Technologies
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  New York City Metropolitan Area
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  47 applicants
# -----------------------------
#
# --- Tên công việc là:  Online Computer Science Tutor - Bilingual (French)
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Reno, NV
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Portugal
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  PHP Developer - Remote
# --- Tên công ty là:  Lee Enterprises
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  East Moline, IL
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  21 applicants
# -----------------------------
#
# --- Tên công việc là:  Nepali Transcriber/ QA  (ट्रान्सक्राइबर/ QA - नेपाली)
# --- Tên công ty là:  TransPerfect
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Koshi Zone, Nepal
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Colombia
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Japan
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Henderson Technology and Coding Tutor
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Henderson, NV
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  DevOps Engineer, Audio Products (Remote)
# --- Tên công ty là:  Avid
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Poland
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  5 applicants
# -----------------------------
#
# --- Tên công việc là:  Customer Service Remote Work from home $15.00 per Hour US only
# --- Tên công ty là:  Global Payments Inc.
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Georgia
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  20 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Chile
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Разработчик Ruby On Rail
# --- Tên công ty là:  Code & Care
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Argentina
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  9 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Russia
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Online Computer Science Tutor - Bilingual (French)
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Indianapolis, IN
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Bilingual Spanish Work from Home Fraud Inbound
# --- Tên công ty là:  Global Payments Inc.
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Florida, United States
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  3 applicants
# -----------------------------
#
# --- Tên công việc là:  Drone Developers
# --- Tên công ty là:  SUPERHIGHWAY Technology
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Bangkok City, Thailand
# --- Thời gian đăng:  8 hours ago
# --- Số lượng người đăng kí:  2 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Israel
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Level 2 Remote Operations Technician
# --- Tên công ty là:  ICS Complete
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Auburn, MA
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  22 applicants
# -----------------------------
#
# --- Tên công việc là:  Online High School Geometry Tutor
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  United States
# --- Thời gian đăng:  5 days ago
# --- Số lượng người đăng kí:  5 applicants
# -----------------------------
#
# --- Tên công việc là:  DevOps/Site Reliability/Systems Engineer (Remote)
# --- Tên công ty là:  Dice
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  United States
# --- Thời gian đăng:  2 weeks ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Customer Support Specialist (APAC/OCEANIA Timezone)
# --- Tên công ty là:  Exodus
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Australia
# --- Thời gian đăng:  4 days ago
# --- Số lượng người đăng kí:  62 applicants
# -----------------------------
#
# --- Tên công việc là:  Onboarding Developer - Remote
# --- Tên công ty là:  Lee Enterprises
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  East Moline, IL
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Remote Linux Certification Tutor
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  United States
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Nepali Transcriber/ QA  (ट्रान्सक्राइबर/ QA - नेपाली)
# --- Tên công ty là:  TransPerfect
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Kathmandu, Bāgmatī, Nepal
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  14 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Philippines
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  TROUBLESHOOTER | USA🗽 fast growing startup🏡 for Property Managers | 🚀 LATAM🌎 | 100% Remote ⌚👌
# --- Tên công ty là:  Prometeo Talent - HR solutions, Global Talent Acquisition Experts, IT RPO
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Quito, Pichincha, Ecuador
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Nepali Transcriber/ QA  (ट्रान्सक्राइबर/ QA - नेपाली)
# --- Tên công ty là:  TransPerfect
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Pokhara, Gandakī, Nepal
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Nepali Transcriber/ QA  (ट्रान्सक्राइबर/ QA - नेपाली)
# --- Tên công ty là:  TransPerfect
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Gandakī, Nepal
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  2 applicants
# -----------------------------
#
# --- Tên công việc là:  Software Engineer II - Java (Remote)
# --- Tên công ty là:  Pieces
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Irving, TX
# --- Thời gian đăng:  12 hours ago
# --- Số lượng người đăng kí:  35 applicants
# -----------------------------
#
# --- Tên công việc là:  ASRC Federal's Software Engineer Virtual Event
# --- Tên công ty là:  ASRC Federal
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  United States
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Luxembourg, Luxembourg, Luxembourg
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Nepali Transcriber/ QA  (ट्रान्सक्राइबर/ QA - नेपाली)
# --- Tên công ty là:  TransPerfect
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Bāgmatī, Nepal
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  9 applicants
# -----------------------------
#
# --- Tên công việc là:  SOFTWARE ENGINEER - UI @ Full Time - 100% Remote
# --- Tên công ty là:  Dice
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  United States
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  23 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Egypt
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  5 applicants
# -----------------------------
#
# --- Tên công việc là:  Telemarketer
# --- Tên công ty là:  DHL Express
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Brisbane, Queensland, Australia
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  65 applicants
# -----------------------------
#
# --- Tên công việc là:  REMOTE - Fullstack Java position-Direct client-W2 -- H1 sponsorship available-OPT can apply
# --- Tên công ty là:  Dice
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Taylor, MI
# --- Thời gian đăng:  4 days ago
# --- Số lượng người đăng kí:  3 applicants
# -----------------------------
#
# --- Tên công việc là:  DevOps/Site Reliability/Systems Engineer (Remote)
# --- Tên công ty là:  Dice
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  United States
# --- Thời gian đăng:  2 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Taiwan
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Switzerland
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Software as a Service Operations Specialist
# --- Tên công ty là:  EBSCO Industries, Inc.
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  United States
# --- Thời gian đăng:  1 day ago
# --- Số lượng người đăng kí:  3 applicants
# -----------------------------
#
# --- Tên công việc là:  Milwaukee ISEE- Middle Level Tutor
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Milwaukee, WI
# --- Thời gian đăng:  4 days ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Python Developer
# --- Tên công ty là:  Virtualmind
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Mexico
# --- Thời gian đăng:  5 days ago
# --- Số lượng người đăng kí:  23 applicants
# -----------------------------
#
# --- Tên công việc là:  Software Engineer
# --- Tên công ty là:  Genophore Inc.
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Kenya
# --- Thời gian đăng:  2 hours ago
# --- Số lượng người đăng kí:  7 applicants
# -----------------------------
#
# --- Tên công việc là:  (Remote) eCommerce Web Developer
# --- Tên công ty là:  Sugatan.io
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Mumbai, Maharashtra, India
# --- Thời gian đăng:  7 hours ago
# --- Số lượng người đăng kí:  13 applicants
# -----------------------------
#
# --- Tên công việc là:  Linux Support Analyst - Work From Home - M
# --- Tên công ty là:  Dice
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  United States
# --- Thời gian đăng:  2 weeks ago
# --- Số lượng người đăng kí:  7 applicants
# -----------------------------
#
# --- Tên công việc là:  Raleigh-Durham ISEE- Middle Level Tutor
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Raleigh, NC
# --- Thời gian đăng:  5 days ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Miami HTML Tutor
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Miami, FL
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Finland
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Software Automation /QA Engineer
# --- Tên công ty là:  NRI Distribution
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Kitchener, ON
# --- Thời gian đăng:  13 hours ago
# --- Số lượng người đăng kí:  12 applicants
# -----------------------------
#
# --- Tên công việc là:  Online Computer Science Tutor - Bilingual (French)
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Lexington, KY
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Software Engineer, Blockchain Integrations
# --- Tên công ty là:  Chainlink Labs
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  London, England, United Kingdom
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  5 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Norway
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Full Stack Developer - UK Remote
# --- Tên công ty là:  iO Associates - UK/EU
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Birmingham, England, United Kingdom
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  32 applicants
# -----------------------------
#
# --- Tên công việc là:  Software Engineer
# --- Tên công ty là:  Payd
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Kuala Lumpur, Federal Territory of Kuala Lumpur, Malaysia
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  33 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Valletta, Malta
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Austria
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Rust Developer (m/f/d)
# --- Tên công ty là:  Qdrant
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Germany
# --- Thời gian đăng:  1 day ago
# --- Số lượng người đăng kí:  10 applicants
# -----------------------------
#
# --- Tên công việc là:  Nepali Transcriber/ QA  (ट्रान्सक्राइबर/ QA - नेपाली)
# --- Tên công ty là:  TransPerfect
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Heṭauā, Nārāyanī, Nepal
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Nepali Transcriber/ QA  (ट्रान्सक्राइबर/ QA - नेपाली)
# --- Tên công ty là:  TransPerfect
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Nārāyanī, Nepal
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Estonia
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Web Development Specialist
# --- Tên công ty là:  Riverbed Technology
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  California, United States
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  13 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Slovakia
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Full Stack Engineer
# --- Tên công ty là:  Experify
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Germany
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  56 applicants
# -----------------------------
#
# --- Tên công việc là:  Azure AD IAM Operational Support Administrator - 100% Remote
# --- Tên công ty là:  TEKsystems
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  New York, NY
# --- Thời gian đăng:  5 days ago
# --- Số lượng người đăng kí:  5 applicants
# -----------------------------
#
# --- Tên công việc là:  HQ - QA Engineer (EMEA Remote)
# --- Tên công ty là:  Jobandtalent
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Madrid, Community of Madrid, Spain
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  3 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Serbia
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Turkey
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  2 applicants
# -----------------------------
#
# --- Tên công việc là:  Software Quality Assurance Tester
# --- Tên công ty là:  Remote92
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Spain
# --- Thời gian đăng:  5 hours ago
# --- Số lượng người đăng kí:  16 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Slovenia
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Technical or Engineering Sales – Virtual Intern or CO-OP
# --- Tên công ty là:  GAO RFID Inc.
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Canada
# --- Thời gian đăng:  11 hours ago
# --- Số lượng người đăng kí:  24 applicants
# -----------------------------
#
# --- Tên công việc là:  Data Associate (Bilingual French)
# --- Tên công ty là:  Numerator
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Mississauga, ON
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  5 applicants
# -----------------------------
#
# --- Tên công việc là:  Junior Software Developer (Remote within Canada)
# --- Tên công ty là:  Rewind
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Ottawa, ON
# --- Thời gian đăng:  1 day ago
# --- Số lượng người đăng kí:  27 applicants
# -----------------------------
#
# --- Tên công việc là:  ServiceNow ATF (Automated Test Framework) - Remote Summer Intern
# --- Tên công ty là:  Realogy
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Madison, NJ
# --- Thời gian đăng:  4 days ago
# --- Số lượng người đăng kí:  16 applicants
# -----------------------------
#
# --- Tên công việc là:  Junior Developer
# --- Tên công ty là:  FNZ Group
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Czechia
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  10 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Greece
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Washington API Tutor
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Washington, DC
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Performance Tester (100% Remote)
# --- Tên công ty là:  Dice
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  San Francisco, CA
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Medical Interpreter
# --- Tên công ty là:  Lnterprepedia
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Singapore
# --- Thời gian đăng:  1 day ago
# --- Số lượng người đăng kí:  23 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Spain
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Web Development Specialist (m|w|d) 99% remote Wien
# --- Tên công ty là:  join.com
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Vienna, Vienna, Austria
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  5 applicants
# -----------------------------
#
# --- Tên công việc là:  Support Advisor (Remote, Melbourne, Australia)
# --- Tên công ty là:  Shopify
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Australia
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  22 applicants
# -----------------------------
#
# --- Tên công việc là:  Site Reliability Engineer
# --- Tên công ty là:  Virtualmind
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Brazil
# --- Thời gian đăng:  5 days ago
# --- Số lượng người đăng kí:  9 applicants
# -----------------------------
#
# --- Tên công việc là:  Fullstack Engineer (Automation Team)
# --- Tên công ty là:  Remote
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Bulgaria
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Fraud Inbound Remote Work from Home $15.00 per hour US only
# --- Tên công ty là:  Global Payments Inc.
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Georgia
# --- Thời gian đăng:  3 days ago
# --- Số lượng người đăng kí:  9 applicants
# -----------------------------
#
# --- Tên công việc là:  Aurora Alibaba Cloud Tutor
# --- Tên công ty là:  Varsity Tutors, a Nerdy Company
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Aurora, CO
# --- Thời gian đăng:  3 weeks ago
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  Web Development Expert (m|w|d) 99% remote
# --- Tên công ty là:  join.com
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Vienna, Vienna, Austria
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  1 applicant
# -----------------------------
#
# --- Tên công việc là:  Software Development Engineer
# --- Tên công ty là:  None
# --- Loại công việc:  Full-time
# --- Lương:  Try Premium for free
# --- Vị trí:  Russia
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  8 applicants
# -----------------------------
#
# --- Tên công việc là:  Technical Outsource Architect Infrastructure (The Netherlands)
# --- Tên công ty là:  Strypes
# --- Loại công việc:  Full-time · Entry level
# --- Lương:  Try Premium for free
# --- Vị trí:  Bulgaria
# --- Thời gian đăng:  2 days ago
# --- Số lượng người đăng kí:  3 applicants
# -----------------------------
#
# --- Tên công việc là:  DevOps Engineer
# --- Tên công ty là:  Plure.com
# --- Loại công việc:  Full-time
# ...
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
#
# --- Tên công việc là:  None
# --- Tên công ty là:  None
# --- Loại công việc:  None
# --- Lương:  None
# --- Vị trí:  None
# --- Thời gian đăng:  None
# --- Số lượng người đăng kí:  None
# -----------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17028/3592311893.py in <module>
#       4     writer.writeheader()
#       5     for linkedin_URL in URLs_all_page:
# ----> 6         driver.get(linkedin_URL)
#       7         #print('- Accessing profile: ', linkedin_URL)
#       8         sleep(3)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     434         Loads a web page in the current browser session.
#     435         """
# --> 436         self.execute(Command.GET, {'url': url})
#     437
#     438     @property
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     420
#     421         params = self._wrap_value(params)
# --> 422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
#     424             self.error_handler.check_response(response)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     419         data = utils.dump_json(params)
#     420         url = f"{self._url}{path}"
# --> 421         return self._request(command_info[0], url, body=data)
#     422
#     423     def _request(self, method, url, body=None):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     441
#     442         if self.keep_alive:
# --> 443             resp = self._conn.request(method, url, body=body, headers=headers)
#     444             statuscode = resp.status
#     445         else:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      76             )
#      77         else:
# ---> 78             return self.request_encode_body(
#      79                 method, url, fields=fields, headers=headers, **urlopen_kw
#      80             )
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     168         extra_kw.update(urlopen_kw)
#     169
# --> 170         return self.urlopen(method, url, **extra_kw)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     373             response = conn.urlopen(method, url, **kw)
#     374         else:
# --> 375             response = conn.urlopen(method, u.request_uri, **kw)
#     376
#     377         redirect_location = redirect and response.get_redirect_location()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443                     # Python 3 (including for exceptions like SystemExit).
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     447             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     438                 # Python 3
#     439                 try:
# --> 440                     httplib_response = conn.getresponse()
#     441                 except BaseException as e:
#     442                     # Remove the TypeError from the exception chain in
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in getresponse(self)
#    1343         try:
#    1344             try:
# -> 1345                 response.begin()
#    1346             except ConnectionError:
#    1347                 self.close()
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# ~\AppData\Local\Programs\Python\Python39\lib\http\client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# ~\AppData\Local\Programs\Python\Python39\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
def get_job_info():
  return  {
      'Tên công việc': '',
      'Tên công ty': None,
      'Vị trí': None,
      'Number of applying': None,
      'Title': '',
      'Description': {
          'Loại công vie':None,
          'Qualifications':None
          },
      
  }
